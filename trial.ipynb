# %%
import pandas as pd
from sqlalchemy import create_engine,text as sql_text
conn_str = "mssql+pymssql://sa:skyblue2009*@192.168.11.3/Simple"
engine = create_engine(conn_str)
with engine.begin() as conn:
    query = sql_text("SELECT *FROM [BATDatabaseRegister].[dbo].[User]")
    df = pd.read_sql_query(query, conn)
    print(df.head())

# %%
conn_str = "mssql+pymssql://sa:skyblue2009*@192.168.11.3/Simple"
engine = create_engine(conn_str)
df.to_sql("User",con=engine,index=False)
# Out:
# 58
